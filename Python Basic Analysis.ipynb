# %%
import pandas as pd
import numpy as np

# %%
oo=pd.read_csv('../data/olympics.csv',skiprows=4)# there are 4 rows that are blank in the csv file

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.shape
# Out:
# (29216, 10)

# %%
oo.shape[0]#get just the # of row
# Out:
# 29216

# %%
oo.shape[1]#get just the # of column
# Out:
# 10

# %%
oo.head(4)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %%
oo.tail(3)
# Out:
#           City  Edition      Sport       Discipline          Athlete  NOC  \
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R  PATRIKEEV, Yuri  ARM
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R    LOPEZ, Mijain  CUB
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R   BAROEV, Khasan  RUS
#
#       Gender       Event Event_gender   Medal
# 29213    Men  96 - 120kg            M  Bronze
# 29214    Men  96 - 120kg            M    Gold
# 29215    Men  96 - 120kg            M  Silver

# %%
oo.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts(ascending=True)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %%
oo.query("Gender=='Women'and Edition >1990").Sport.value_counts()
# Out:
# Aquatics             771
# Athletics            430
# Rowing               306
# Gymnastics           266
# Hockey               239
# Handball             220
# Football             208
# Volleyball           204
# Softball             180
# Basketball           179
# Judo                 140
# Canoe / Kayak        120
# Fencing              119
# Equestrian            93
# Cycling               90
# Shooting              88
# Sailing               78
# Weightlifting         63
# Archery               60
# Badminton             60
# Table Tennis          51
# Tennis                46
# Taekwondo             40
# Wrestling             28
# Triathlon              9
# Modern Pentathlon      9
# Name: Sport, dtype: int64

# %%
oo.query("Gender=='Men'and Edition >1990").Sport.value_counts()
# Out:
# Aquatics             727
# Athletics            472
# Rowing               426
# Baseball             335
# Canoe / Kayak        300
# Wrestling            265
# Football             247
# Hockey               242
# Cycling              234
# Boxing               232
# Handball             223
# Gymnastics           212
# Volleyball           203
# Fencing              202
# Sailing              183
# Basketball           179
# Shooting             143
# Judo                 140
# Equestrian           134
# Weightlifting        131
# Badminton             60
# Archery               60
# Table Tennis          51
# Tennis                48
# Taekwondo             40
# Modern Pentathlon     24
# Triathlon              9
# Name: Sport, dtype: int64

# %%
counts=oo.Sport.value_counts()
counts.plot(kind='barh',figsize=(20,10))

# %%
aquatics=oo.query("Sport=='Aquatics'")

# %%
aquatics.Edition.plot(kind='bar')

# %%
aquatics
# Out:
#           City  Edition     Sport  Discipline                Athlete  NOC  \
# 0       Athens     1896  Aquatics    Swimming          HAJOS, Alfred  HUN
# 1       Athens     1896  Aquatics    Swimming       HERSCHMANN, Otto  AUT
# 2       Athens     1896  Aquatics    Swimming      DRIVAS, Dimitrios  GRE
# 3       Athens     1896  Aquatics    Swimming     MALOKINIS, Ioannis  GRE
# 4       Athens     1896  Aquatics    Swimming     CHASAPIS, Spiridon  GRE
# 5       Athens     1896  Aquatics    Swimming  CHOROPHAS, Efstathios  GRE
# 6       Athens     1896  Aquatics    Swimming          HAJOS, Alfred  HUN
# 7       Athens     1896  Aquatics    Swimming       ANDREOU, Joannis  GRE
# 8       Athens     1896  Aquatics    Swimming  CHOROPHAS, Efstathios  GRE
# 9       Athens     1896  Aquatics    Swimming          NEUMANN, Paul  AUT
# 10      Athens     1896  Aquatics    Swimming      PEPANOS, Antonios  GRE
# 151      Paris     1900  Aquatics    Swimming         HALMAY, Zoltan  HUN
# ...

# %%
aquatics
# Out:
#           City  Edition     Sport  Discipline                Athlete  NOC  \
# 0       Athens     1896  Aquatics    Swimming          HAJOS, Alfred  HUN
# 1       Athens     1896  Aquatics    Swimming       HERSCHMANN, Otto  AUT
# 2       Athens     1896  Aquatics    Swimming      DRIVAS, Dimitrios  GRE
# 3       Athens     1896  Aquatics    Swimming     MALOKINIS, Ioannis  GRE
# 4       Athens     1896  Aquatics    Swimming     CHASAPIS, Spiridon  GRE
# 5       Athens     1896  Aquatics    Swimming  CHOROPHAS, Efstathios  GRE
# 6       Athens     1896  Aquatics    Swimming          HAJOS, Alfred  HUN
# 7       Athens     1896  Aquatics    Swimming       ANDREOU, Joannis  GRE
# 8       Athens     1896  Aquatics    Swimming  CHOROPHAS, Efstathios  GRE
# 9       Athens     1896  Aquatics    Swimming          NEUMANN, Paul  AUT
# 10      Athens     1896  Aquatics    Swimming      PEPANOS, Antonios  GRE
# 151      Paris     1900  Aquatics    Swimming         HALMAY, Zoltan  HUN
# ...

# %%
aquatics.Edition.value_counts()
# Out:
# 2008    347
# 2004    332
# 2000    329
# 1996    262
# 1992    228
# 1988    202
# 1984    192
# 1972    177
# 1968    177
# 1980    159
# 1976    159
# 1964    145
# 1960    128
# 1924    109
# 1956     98
# 1952     96
# 1936     94
# 1948     91
# 1932     88
# 1928     87
# 1920     87
# 1912     78
# 1900     61
# 1908     48
# 1904     43
# 1896     11
# Name: Edition, dtype: int64

# %%
aquatics.Edition.value_counts().plot(kind='bar')

# %%
oo.dtypes
# Out:
# City            object
# Edition          int64
# Sport           object
# Discipline      object
# Athlete         object
# NOC             object
# Gender          object
# Event           object
# Event_gender    object
# Medal           object
# dtype: object

# %%
oo.Athlete.sort_values(ascending=False).head()
# Out:
# 8051    ÖSTRAND, Per-Olof
# 596            ÖSTMO, Ole
# 621            ÖSTMO, Ole
# 608            ÖSTMO, Ole
# 603            ÖSTMO, Ole
# Name: Athlete, dtype: object

# %%
oo.sort_values(by=['Edition','Athlete']).head(10)
# Out:
#        City  Edition       Sport    Discipline                   Athlete  NOC  \
# 7    Athens     1896    Aquatics      Swimming          ANDREOU, Joannis  GRE
# 82   Athens     1896  Gymnastics   Artistic G.  ANDRIAKOPOULOS, Nicolaos  GRE
# 110  Athens     1896  Gymnastics   Artistic G.  ANDRIAKOPOULOS, Nicolaos  GRE
# 111  Athens     1896  Gymnastics   Artistic G.    ATHANASOPOULOS, Spyros  GRE
# 48   Athens     1896     Cycling  Cycling Road            BATTEL, Edward  GBR
# 19   Athens     1896   Athletics     Athletics             BLAKE, Arthur  USA
# 134  Athens     1896      Tennis        Tennis              BOLAND, John  ZZX
# 140  Athens     1896      Tennis        Tennis              BOLAND, John  GBR
# 13   Athens     1896   Athletics     Athletics             BURKE, Thomas  USA
# 21   Athens     1896   Athletics     Athletics             BURKE, Thomas  USA
#
#     Gender                 Event Event_gender   Medal
# 7      Men       1200m freestyle            M  Silver
# ...

# %%
oo[(oo.Medal=='Gold') & (oo.Gender=='Women')].head()
# Out:
#          City  Edition    Sport Discipline                Athlete  NOC Gender  \
# 417     Paris     1900     Golf       Golf  ABBOTT, Margaret Ives  USA  Women
# 641     Paris     1900   Tennis     Tennis      COOPER, Charlotte  GBR  Women
# 649     Paris     1900   Tennis     Tennis      COOPER, Charlotte  GBR  Women
# 710  St Louis     1904  Archery    Archery  HOWELL, Matilda Scott  USA  Women
# 713  St Louis     1904  Archery    Archery  HOWELL, Matilda Scott  USA  Women
#
#                                        Event Event_gender Medal
# 417                               individual            W  Gold
# 641                            mixed doubles            X  Gold
# 649                                  singles            W  Gold
# 710  double columbia round (50y - 40y - 30y)            W  Gold
# 713        double national round (60y - 50y)            W  Gold

# %%
oo.query("Medal=='Gold' & Gender=='Women'").head() #same as above but shorter
# Out:
#          City  Edition    Sport Discipline                Athlete  NOC Gender  \
# 417     Paris     1900     Golf       Golf  ABBOTT, Margaret Ives  USA  Women
# 641     Paris     1900   Tennis     Tennis      COOPER, Charlotte  GBR  Women
# 649     Paris     1900   Tennis     Tennis      COOPER, Charlotte  GBR  Women
# 710  St Louis     1904  Archery    Archery  HOWELL, Matilda Scott  USA  Women
# 713  St Louis     1904  Archery    Archery  HOWELL, Matilda Scott  USA  Women
#
#                                        Event Event_gender Medal
# 417                               individual            W  Gold
# 641                            mixed doubles            X  Gold
# 649                                  singles            W  Gold
# 710  double columbia round (50y - 40y - 30y)            W  Gold
# 713        double national round (60y - 50y)            W  Gold

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
#challenge 1 Which events did Jesse Owens win a medal

oo[oo.Athlete.str.contains('Jesse')]
# Out:
#                         City  Edition       Sport     Discipline  \
# 1522                  London     1908      Hockey         Hockey
# 1773                  London     1908    Shooting       Shooting
# 6427                  Berlin     1936   Athletics      Athletics
# 6439                  Berlin     1936   Athletics      Athletics
# 6456                  Berlin     1936   Athletics      Athletics
# 6523                  Berlin     1936   Athletics      Athletics
# 7444                  London     1948  Basketball     Basketball
# 9070   Melbourne / Stockholm     1956   Athletics      Athletics
# 11462                  Tokyo     1964      Rowing         Rowing
# 13113                 Munich     1972      Boxing         Boxing
# 26519                 Athens     2004      Hockey         Hockey
# 27479                Beijing     2008    Aquatics     Water polo
# 28065                Beijing     2008     Cycling  Cycling Track
#
# ...

# %%
oo[oo.Athlete=='OWENS, Jesse'].Event
# Out:
# 6427            100m
# 6439            200m
# 6456    4x100m relay
# 6523       long jump
# Name: Event, dtype: object

# %%
oo.query("Athlete=='OWENS, Jesse'").Event
# Out:
# 6427            100m
# 6439            200m
# 6456    4x100m relay
# 6523       long jump
# Name: Event, dtype: object

# %%
#challenge 2 which country has won the most men's gold medals in singles badminton over the years? 
#Sort the results alphabetically by the players name

oo.query("Medal=='Gold' & Sport=='Badminton' & Gender=='Men'").sort_values(by='Athlete').NOC.value_counts()
# Out:
# INA    8
# KOR    6
# CHN    4
# DEN    1
# Name: NOC, dtype: int64

# %%
#which three countries have won the most medals in recent years (1984-2008)
oo.query("Edition >= 1984").NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
#display the male gold medal winners for 100m track and field sprint over the years
#list the results by the most recent. Show Olympic city,Edition, Athlete,and country
oo2=oo.query("Gender=='Men' & Medal=='Gold'& Event=='100m'").sort_values(by='Edition',ascending=False)[['City','Edition','Athlete','NOC']]

# %%
oo2
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %%
oo[(oo.Gender=='Men') &(oo.Event=='100m')&(oo.Medal=='Gold')]
# Out:
#                         City  Edition      Sport Discipline  \
# 13                    Athens     1896  Athletics  Athletics
# 231                    Paris     1900  Athletics  Athletics
# 737                 St Louis     1904  Athletics  Athletics
# 1191                  London     1908  Athletics  Athletics
# 2022               Stockholm     1912  Athletics  Athletics
# 2996                 Antwerp     1920  Athletics  Athletics
# 4236                   Paris     1924  Athletics  Athletics
# 5095               Amsterdam     1928  Athletics  Athletics
# 5806             Los Angeles     1932  Athletics  Athletics
# 6427                  Berlin     1936  Athletics  Athletics
# 7302                  London     1948  Athletics  Athletics
# 8121                Helsinki     1952  Athletics  Athletics
# 9009   Melbourne / Stockholm     1956  Athletics  Athletics
# 9924                    Rome     1960  Athletics  Athletics
# 10823                  Tokyo     1964  Athletics  Athletics
# ...
